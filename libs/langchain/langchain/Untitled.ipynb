# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [autoreload of langchain.utilities failed: Traceback (most recent call last):
#   File "C:\Users\21kti\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\21kti\AppData\Roaming\Python\Python39\site-packages\IPython\extensions\autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "C:\Users\21kti\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 855, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
# ...

# %%
from langchain.tools.google_finance import GoogleFinanceQueryRun
from langchain.utilities.google_finance import GoogleFinanceAPIWrapper

import os
os.environ["SERPAPI_API_KEY"] = "e0ea60630cdd4d70f227462f1d3cd0b9900a789ed572ad536d1de0c83b4cc972"
tool = GoogleFinanceQueryRun(api_wrapper=GoogleFinanceAPIWrapper())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from langchain.tools.google_finance import GoogleFinanceQueryRun
#       2 from langchain.utilities.google_finance import GoogleFinanceAPIWrapper
#       4 import os
#
# File ~\Desktop\d01-google-scholar\langchain\libs\langchain\langchain\tools\__init__.py:21
#       1 """**Tools** are classes that an Agent uses to interact with the world.
#       2
#       3 Each tool has a **description**. Agent uses the description to choose the right
#    (...)
#      17     CallbackManagerForToolRun, AsyncCallbackManagerForToolRun
#      18 """
#      19 from typing import Any
# ---> 21 from langchain.tools.base import BaseTool, StructuredTool, Tool, tool
#      23 # Used for internal purposes
#      24 _DEPRECATED_TOOLS = {"PythonAstREPLTool", "PythonREPLTool"}
#
# ...
